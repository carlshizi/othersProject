# %%
import pandas as pd

df_covid = pd.read_csv('node_245_field_data_table_und_0.csv')
df_covid
# Out:
#             County or Counties Served                         Organization  \
# 0                           Alamance    Alamance County Health Department
# 1      Alamance, Guilford, Rockingham                         Cone Health
# 2    Alamance, Guilford, Rockingham,      Cone Health Wesley Long Hospital
# 3                           Alexander   Alexander County Health Department
# 4                Alexander, Iredell,                 Iredell Health System
# ..                                ...                                  ...
# 131                            Wilkes      Wilkes County Health Department
# 132                            Wilson                Wilson Medical Center
# 133                            Wilson      Wilson County Health Department
# 134                            Yadkin  Yadkin County Human Services Agency
# 135                            Yancey      Yancey County Health Department
#
#                                                Website  \
# ...

# %%
# df_A = df_covid['County or Counties Served'].tolist()
# df_B = df_covid['Organization'].tolist()
# df_C = df_covid['Website'].tolist()
# df_D = (df_covid['Phone Number'].fillna('')).tolist()
# df_E = (df_covid['Email'].fillna('')).tolist()
# df_F = (df_covid['More Information'].fillna('')).tolist()
# df_Column = df_covid.columns.tolist()
# df_Column
# Out:
# ['<a href="https://www.facebook.com/AlamanceCountyHealthDept/">Facebook<a/>',
#  '<a href="http://www.facebook.com/conehealth">Facebook<a/>',
#  '',
#  '<a href="https://www.facebook.com/alexandercounty/ ">Facebook<a/>',
#  '',
#  '',
#  '<a href="https://www.facebook.com/AppHealthCare-209459329094732/">Facebook<a/>',
#  '<a href="https://m.facebook.com/Anson-County-Health-Department-308376465957640/">Facebook<a/>',
#  '',
#  '<a href="http://averycountync.gov/">More info; <a href="https://www.facebook.com/pages/category/Medical-Center/Mitchell-County-Health-Department-122415704510362/">Facebook<a/>',
#  '',
#  '<a href="https://www.facebook.com/BeaufortCountyHealthDept/">Facebook<a/>',
#  '',
#  '<a href="https://www.facebook.com/ARHS.NC/">Facebook<a/>; <a href="https://www.arhs-nc.org/contact/form/?ID=ARHS">Contact Form<a/>',
#  '<a href="https://www.facebook.com/BladenHHS  ">Facebook<a/>; ; Bladen COVID Hotline for ages 75 and older: 910-872-6291 Monday-Friday 9:30am-4:30pm',
# ...

# %%
# First Row
df_covid['County or Counties Served']
df_covid['County or Counties Served'].tolist()
# Out:
# ['Alamance ',
#  'Alamance, Guilford, Rockingham',
#  'Alamance, Guilford, Rockingham, ',
#  'Alexander',
#  'Alexander, Iredell, ',
#  'Alexander, Catawba, Lincoln',
#  'Alleghany, Ashe, Watauga ',
#  'Anson',
#  'Anson, Cabarrus, Cleveland, Lincoln, Mecklenburg, Stanly, Union',
#  'Avery',
#  'Avery, Watauga',
#  'Beaufort',
#  'Beaufort, Bertie, Chowan, Dare, Duplin, Edgecombe, Halifax, Hertford, Pitt ',
#  'Bertie',
#  'Bladen',
#  'Brunswick ',
#  'Buncombe ',
#  'Buncombe, Henderson',
#  'Burke',
#  'Burke ',
#  'Cabarrus ',
#  'Caldwell ',
#  'Caldwell ',
#  'Camden',
#  'Carteret',
#  'Carteret',
#  'Caswell',
#  'Catawba',
#  'Chatham',
#  'Chatham',
#  'Cherokee ',
#  'Chowan',
#  'Clay',
#  'Cleveland',
#  'Columbus',
#  'Craven',
#  'Craven',
#  'Cumberland  ',
#  'Currituck',
#  'Dare ',
#  'Davidson',
#  'Davidson, Davie, Forsyth, Guilford, Wilkes',
#  'Davie',
#  'Duplin',
#  'Durham',
#  'Durham',
#  'Durham ',
#  'Edgecombe ',
#  'Edgecombe, Nash',
#  'Forsyth ',
# ...

# %%
# Second Row... Every subsequent row will have same formula
df_covid['County or Counties Served']
# Out:
# 0                             Alamance
# 1        Alamance, Guilford, Rockingham
# 2      Alamance, Guilford, Rockingham,
# 3                             Alexander
# 4                  Alexander, Iredell,
#                      ...
# 131                              Wilkes
# 132                              Wilson
# 133                              Wilson
# 134                              Yadkin
# 135                              Yancey
# Name: County or Counties Served, Length: 136, dtype: object

# %%
dfcnan = df_covid['More Information'].fillna('')
dfcnan.tolist()
# Out:
# ['<a href="https://www.facebook.com/AlamanceCountyHealthDept/">Facebook<a/>',
#  '<a href="http://www.facebook.com/conehealth">Facebook<a/>',
#  '',
#  '<a href="https://www.facebook.com/alexandercounty/ ">Facebook<a/>',
#  '',
#  '',
#  '<a href="https://www.facebook.com/AppHealthCare-209459329094732/">Facebook<a/>',
#  '<a href="https://m.facebook.com/Anson-County-Health-Department-308376465957640/">Facebook<a/>',
#  '',
#  '<a href="http://averycountync.gov/">More info; <a href="https://www.facebook.com/pages/category/Medical-Center/Mitchell-County-Health-Department-122415704510362/">Facebook<a/>',
#  '',
#  '<a href="https://www.facebook.com/BeaufortCountyHealthDept/">Facebook<a/>',
#  '',
#  '<a href="https://www.facebook.com/ARHS.NC/">Facebook<a/>; <a href="https://www.arhs-nc.org/contact/form/?ID=ARHS">Contact Form<a/>',
#  '<a href="https://www.facebook.com/BladenHHS  ">Facebook<a/>; ; Bladen COVID Hotline for ages 75 and older: 910-872-6291 Monday-Friday 9:30am-4:30pm',
# ...

# %%
df_covid.columns.tolist()
# Out:
# ['County or Counties Served',
#  'Organization',
#  'Website',
#  'Phone Number',
#  'Email',
#  'More Information']

# %%
# df_A = df_covid['County or Counties Served'].tolist()
# df_B = df_covid['Organization'].tolist()
# df_C = df_covid['Website'].tolist()
# df_D = (df_covid['Phone Number'].fillna('')).tolist()
# df_E = (df_covid['Email'].fillna('')).tolist()
# df_F = (df_covid['More Information'].fillna('')).tolist()
# df_Column = df_covid.columns.tolist()
df_F = (df_covid['More Information'].fillna(''))
# df_F['More Information']=df_F['More Information'].str.replace('<a/>''</a>')
# df_covid['More Information']
df_F = (df_covid['More Information'].fillna('')).str.replace('<a/>','</a>')
df_F
# Out:
# 0      <a href="https://www.facebook.com/AlamanceCoun...
# 1      <a href="http://www.facebook.com/conehealth">F...
# 2
# 3      <a href="https://www.facebook.com/alexandercou...
# 4
#                              ...
# 131    <a href="https://www.facebook.com/WilkesCounty...
# 132
# 133    <a href="https://www.facebook.com/wilsoncounty...
# 134    <a href="https://www.facebook.com/YadkinCounty...
# 135    <a href="https://www.facebook.com/pages/catego...
# Name: More Information, Length: 136, dtype: object
